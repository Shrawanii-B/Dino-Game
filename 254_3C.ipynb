# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrawanii-B/Dino-Game/blob/main/254_3C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")
print(iris.head(10))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# #HISTOGRAM

# %%
plt.figure(figsize=(7,4))
sns.histplot(iris['sepal_length'], kde=True)
plt.title('Histogram of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #BOXPLOT

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=iris['sepal_length'], orientation='horizontal')
plt.title('Boxplot of Sepal Length')

plt.show()

# %% [markdown]
# #COUNTPLOT

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=iris['species'])
plt.title('Count of each Iris Species')
plt.show()

# %% [markdown]
# #SCATTERPLOT

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris, hue='species')
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %% [markdown]
# #PAIRPLOT

# %%
sns.pairplot(iris, hue='species')
plt.suptitle('Pairplot of Iris Features', y=1.02)
plt.show()

# %% [markdown]
# #HEATMAP

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_iris = iris.select_dtypes(include='number')

plt.figure(figsize=(6,5))
sns.heatmap(numeric_iris.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
